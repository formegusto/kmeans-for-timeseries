# %%
# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload

# %%
from modules.Utils import KETIDB

db = KETIDB()

# %%
# KETIDB Utils Test
db.connect()

datas = db.find_random(processing=True)
print(datas)

db.close()
# Out:
# connect KETIDB,,,
# connect success!!
# ('아파트3-103-2018', {'봄':           date      0      1      2      3  ...     92     93     94     95  month
# 0   2018-05-01  0.126  0.034  0.055  0.067  ...  0.105  0.193  0.136  0.057      5
# 1   2018-05-02  0.063  0.034  0.035  0.056  ...  0.127  0.073  0.055  0.104      5
# 2   2018-05-03  0.076  0.031  0.064  0.062  ...  0.056  0.057  0.084  0.032      5
# 3   2018-05-04  0.063  0.067  0.054  0.021  ...  0.059  0.080  0.063  0.070      5
# 4   2018-05-05  0.069  0.063  0.068  0.056  ...  0.067  0.065  0.038  0.037      5
# ..         ...    ...    ...    ...    ...  ...    ...    ...    ...    ...    ...
# 360 2019-04-26  0.059  0.070  0.068  0.057  ...  0.036  0.034  0.072  0.054      4
# 361 2019-04-27  0.052  0.022  0.037  0.050  ...  0.076  0.067  0.077  0.059      4
# 362 2019-04-28  0.067  0.050  0.027  0.022  ...  0.057  0.048  0.094  0.089      4
# 363 2019-04-29  0.028  0.068  0.069  0.067  ...  0.058  0.035  0.013  0.042      4
# ...
