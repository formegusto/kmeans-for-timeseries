 '아파트2-3-801',
 '아파트2-2-1401',
 '아파트1-101-904',
 '아파트1-103-606',
 '아파트2-5-1014',
 '아파트1-102-703',
 '아파트2-4-610',
 '아파트1-103-1502',
 '아파트2-4-405',
 '아파트3-103-110',
 '아파트2-4-709',
 '아파트2-5-1009',
 '아파트1-102-1402',
 '아파트3-101-1507',
 '아파트1-103-1201',
 '아파트4-102-104',
 '아파트1-103-1406',
 '아파트3-102-303',
 '아파트4-103-1406',
 '아파트1-103-1302',
 '아파트2-2-302',
 '아파트4-101-104',
 '아파트3-102-201',
 '아파트3-103-1813',
 '아파트1-104-507',
 '아파트4-103-1309',
 '아파트4-103-610',
 '아파트1-101-1102',
 '아파트1-103-203',
 '아파트1-103-1404',
 '아파트2-5-1101',
 '아파트3-102-1005',
 '아파트3-103-820',
 '아파트1-101-504',
 '아파트2-5-911',
 '아파트3-102-801',
 '아파트3-102-903',
 '아파트2-5-1111',
 '아파트4-103-706',
 '아파트1-101-1504',
 '아파트4-104-1001',
 '아파트2-2-1103',
 '아파트2-5-312',
 '아파트1-102-401',
 '아파트1-102-801',
 '아파트4-105-103',
 '아파트1-101-502',
 '아파트2-4-106',
 '아파트1-103-505',
 '아파트4-103-906',
 '아파트2-4-407',
 '아파트1-104-1007',
 '아파트1-102-1501',
 '아파트3-103-1726',
 '아파트1-101-404',
 '아파트1-102-704',
 '아파트3-102-1703',
 '아파트4-103-1104',
 '아파트4-103-708',
 '아파트2-5-1105',
 '아파트1-103-801',
 '아파트1-103-1805',
 '아파트2-2-707',
 '아파트3-103-325',
 '아파트4-103-905',
 '아파트2-2-403',
 '아파트1-103-1803',
 '아파트2-5-1013',
 '아파트1-103-1804']

# %%
tss_transition = pd.DataFrame(columns=['K','tss','wss', 'ecv', 'og_length', 'new_length', 'sequence'])
# uid_check = ['아파트1-104-1208']

db.connect()

for idx, uid in enumerate(uid_check):
    datas = db.find_one(uid=uid,processing=True)
    datas.merging()
    print("{}: pattern recognition start".format(datas.uid))
    km = KMeans(datas.merge_datas['가을'], logging=False )
    km.run()
    
    tss_transition.loc[uid] = [
        km.K,
        km.tss,
        km.wss,
        km.ecv,
        km.og_length,
        km.new_length,
        km.sequence
    ]
    
    print(tss_transition)

db.close()
# Out:
# connect KETIDB,,,
# connect success!!
# 아파트4-101-1102: pattern recognition start
# ---Init KMeans---
# ---K Setting 6 ---
# ---6:Clustering Start---
# ---Now 1---
# ---First Cluster Group Init---
# ---Now 2---
# ---Now 3---
# ---Now 4---
# ---Now 5---
# ---Now 6---
# ---Now 7---
# ---Now 8---
# ---Now 9---
# ---Now 10---
# ---Now 11---
# ---Now 12---
# ---Now 13---
#                  K        tss        wss        ecv  og_length  new_length  \
# 아파트4-101-1102  6.0  24.157096  16.281143  32.603064       91.0        83.0
#
#                sequence
# 아파트4-101-1102      13.0
# 아파트3-102-505: pattern recognition start
# ---Init KMeans---
# ---K Setting 7 ---
# ---7:Clustering Start---
# ---Now 1---
# ---First Cluster Group Init---
# ---Now 2---
# ---Now 3---
# ---Now 4---
# ---Now 5---
# ---Now 6---
# ---Now 7---
# ---Now 8---
#                  K        tss        wss        ecv  og_length  new_length  \
# 아파트4-101-1102  6.0  24.157096  16.281143  32.603064       91.0        83.0
# ...

# %%
tss_transition.sort_values(by=['ecv'], ascending=False).iloc[:10]
# Out:
#                  K         tss        wss        ecv  og_length  new_length  \
# 아파트1-101-704   6.0    0.046336   0.000359  99.224747       91.0        68.0
# 아파트3-103-803   7.0   44.877228   8.713844  80.582928       91.0        88.0
# 아파트1-103-502   6.0   41.794404   8.550098  79.542482       91.0        69.0
# 아파트2-3-1002    7.0   22.716827   6.285161  72.332575       91.0        85.0
# 아파트2-2-302     7.0  148.454788  41.480239  72.058672       91.0        86.0
# 아파트1-104-408   6.0    2.117512   0.612033  71.096590       91.0        76.0
# 아파트1-101-404   6.0   53.200284  18.333076  65.539515       91.0        76.0
# 아파트3-101-703   7.0   46.219332  17.362424  62.434713       91.0        85.0
# 아파트2-5-814     6.0   20.148213   7.600878  62.275177       91.0        84.0
# 아파트1-101-1504  7.0   62.010165  25.927983  58.187527       91.0        87.0
#
#                sequence
# 아파트1-101-704        5.0
# 아파트3-103-803        9.0
# 아파트1-103-502        5.0
# 아파트2-3-1002         5.0
# ...

# %%
tss_transition['ecv'].mean()
# Out:
# 41.54268837605301

# %%
dr_datas = km.dimension_reduction()
dr_datas['cost'] = [0 for idx in range(0, len(dr_datas.index))]
for cost, value in enumerate(dr_datas.sort_values(by=['x']).index):
    print(value, cost)
    og_cost = dr_datas.loc[value]['cost']
    og_cost += cost
    dr_datas.loc[value, 'cost'] = og_cost
    
for cost, value in enumerate(dr_datas.sort_values(by=['y'], ascending=False).index):
    print(value, cost)
    og_cost = dr_datas.loc[value]['cost']
    og_cost += cost
    dr_datas.loc[value, 'cost'] = og_cost

dr_datas.sort_values(by=['cost'])
# Out:
# 2018-09-15 00:00:00 0
# 2018-10-21 00:00:00 1
# 2018-10-13 00:00:00 2
# 2018-11-02 00:00:00 3
# 2018-10-04 00:00:00 4
# 2018-10-29 00:00:00 5
# 2018-09-13 00:00:00 6
# 2018-10-28 00:00:00 7
# 2018-10-27 00:00:00 8
# 2018-10-07 00:00:00 9
# 2018-10-17 00:00:00 10
# 2018-09-06 00:00:00 11
# 2018-11-29 00:00:00 12
# 2018-09-12 00:00:00 13
# 2018-09-08 00:00:00 14
# 2018-09-02 00:00:00 15
# 2018-09-30 00:00:00 16
# 2018-09-14 00:00:00 17
# 2018-11-24 00:00:00 18
# 2018-11-01 00:00:00 19
# 2018-11-25 00:00:00 20
# 2018-09-09 00:00:00 21
# 2018-11-06 00:00:00 22
# 2018-10-25 00:00:00 23
# 2018-09-11 00:00:00 24
# 2018-10-26 00:00:00 25
# 2018-09-10 00:00:00 26
# 2018-10-10 00:00:00 27
# 2018-09-29 00:00:00 28
# 2018-10-23 00:00:00 29
# 2018-09-16 00:00:00 30
# 2018-10-30 00:00:00 31
# 2018-10-19 00:00:00 32
# 2018-11-04 00:00:00 33
# 2018-10-03 00:00:00 34
# 2018-10-20 00:00:00 35
# 2018-10-12 00:00:00 36
# 2018-09-20 00:00:00 37
# 2018-11-26 00:00:00 38
# 2018-10-18 00:00:00 39
# ...

# %%
dr_datas.sort_values(by=['x','y'], ascending=[True, False])
# Out:
#                    x         y   cost
# 2018-09-15  0.000000  0.947556    1.0
# 2018-10-21  0.049188  0.888119    4.0
# 2018-10-13  0.051082  0.868343    8.0
# 2018-11-02  0.056874  0.898994    5.0
# 2018-10-04  0.057360  0.886949    8.0
# ...              ...       ...    ...
# 2018-11-16  0.860098  0.479645  140.0
# 2018-11-28  0.884962  0.753813  108.0
# 2018-11-21  0.897962  0.575959  133.0
# 2018-11-15  0.947329  1.000000   82.0
# 2018-11-10  1.000000  0.427446  150.0
#
# [84 rows x 3 columns]
