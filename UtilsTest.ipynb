# %%
# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload

# %%
from modules.Utils import KETIDB
from modules.KMeans import KMeans

db = KETIDB()

# %%
# KETIDB Utils Test
db.connect()

for idx in range(0, 100):
    datas = db.find_random(save=True, processing=True)
    datas.merging()
    print("{}: pattern recognition start".format(datas.uid))
    KMeans(datas.merge_datas['봄']).run()

db.close()
# Out:
# connect KETIDB,,,
# connect success!!
# 아파트3-102-602: pattern recognition start
# ---Init KMeans---
# ---init TSS Check---
# - calc TSS(Total Sum Of Squareds Success! -25.747618815217386-
# ---Remove One Pattern---
# ---Dimension Reduction---
# - remove one pattern success: 92 => 92
# - calc TSS(Total Sum Of Squareds Success! -25.747618815217386-
# ---Remove Outliers---
# - dis_check: 0.4861650847082305, sim_check: 0.07107694819153931
# - remove outlier success: 92 => 81
# - calc TSS(Total Sum Of Squareds Success! -16.259727380080342-
# ---K Setting 6 ---
# ---6:Clustering Start---
# ---Now 1---
# ---First Cluster Group Init---
# ---Init Cluster---
# ---First K Is Mean Pattern---
# ---Rest K Select---
# ---Divide Index---
# 1: calc... [80, 0]
# 1: [80, 0, 40]
# 2: calc... [80, 40, 0]
# 2: calc... [80, 40, 0, 60]
# 2: [80, 40, 0, 60, 20]
# 4: calc... [80, 60, 40, 20, 0]
# 4: calc... [80, 60, 40, 20, 0, 70]
# 4: calc... [80, 60, 40, 20, 0, 70, 50]
# 4: calc... [80, 60, 40, 20, 0, 70, 50, 30]
# 4: [80, 60, 40, 20, 0, 70, 50, 30, 10]
# -1: K Setting Okay
# -2: K Setting Okay
# -3: K Setting Okay
# -4: K Setting Okay
# -5: K Setting Okay
# ---Cluster Init Okay KMeans Start---
# - calc TSS(Total Sum Of Squareds Success! -16.259727380080342-
# - calc WSS(Within clusterSum Of Squares) Success! -12.512314044896025-
# - calc ECV(Explained Cluster Variance) Success! -23.047208895859118-
# 1 : TSS: 16.259727380080342, WSS: 12.512314044896025, ECV: 23.047208895859118
# ---Now 2---
# ---Cluster Init Okay KMeans Start---
# - calc TSS(Total Sum Of Squareds Success! -16.259727380080342-
# - calc WSS(Within clusterSum Of Squares) Success! -10.880780748450414-
# - calc ECV(Explained Cluster Variance) Success! -33.08140724560752-
# 2 : TSS: 16.259727380080342, WSS: 10.880780748450414, ECV: 33.08140724560752
# ---Now 3---
# ---Cluster Init Okay KMeans Start---
# - calc TSS(Total Sum Of Squareds Success! -16.259727380080342-
# - calc WSS(Within clusterSum Of Squares) Success! -10.186078109127253-
# - calc ECV(Explained Cluster Variance) Success! -37.35394283666691-
# 3 : TSS: 16.259727380080342, WSS: 10.186078109127253, ECV: 37.35394283666691
# ---Now 4---
# ---Cluster Init Okay KMeans Start---
# - calc TSS(Total Sum Of Squareds Success! -16.259727380080342-
# - calc WSS(Within clusterSum Of Squares) Success! -9.369720654187672-
# - calc ECV(Explained Cluster Variance) Success! -42.37467557010556-
# 4 : TSS: 16.259727380080342, WSS: 9.369720654187672, ECV: 42.37467557010556
# ---Now 5---
# ---Cluster Init Okay KMeans Start---
# - calc TSS(Total Sum Of Squareds Success! -16.259727380080342-
# - calc WSS(Within clusterSum Of Squares) Success! -9.21982495999279-
# - calc ECV(Explained Cluster Variance) Success! -43.29655876464496-
# 5 : TSS: 16.259727380080342, WSS: 9.21982495999279, ECV: 43.29655876464496
# ---Now 6---
# ---Cluster Init Okay KMeans Start---
# - calc TSS(Total Sum Of Squareds Success! -16.259727380080342-
# - calc WSS(Within clusterSum Of Squares) Success! -9.100946963237348-
# - calc ECV(Explained Cluster Variance) Success! -44.02767801392019-
# 6 : TSS: 16.259727380080342, WSS: 9.100946963237348, ECV: 44.02767801392019
# ---Now 7---
# ---Cluster Init Okay KMeans Start---
# - calc TSS(Total Sum Of Squareds Success! -16.259727380080342-
# - calc WSS(Within clusterSum Of Squares) Success! -8.948085395732408-
# - calc ECV(Explained Cluster Variance) Success! -44.96780181754687-
# 7 : TSS: 16.259727380080342, WSS: 8.948085395732408, ECV: 44.96780181754687
# ---Now 8---
# ---Cluster Init Okay KMeans Start---
# - calc TSS(Total Sum Of Squareds Success! -16.259727380080342-
# - calc WSS(Within clusterSum Of Squares) Success! -8.917486267006804-
# - calc ECV(Explained Cluster Variance) Success! -45.1559914963178-
# 8 : TSS: 16.259727380080342, WSS: 8.917486267006804, ECV: 45.1559914963178
# ---Now 9---
# ---Cluster Init Okay KMeans Start---
# - calc TSS(Total Sum Of Squareds Success! -16.259727380080342-
# - calc WSS(Within clusterSum Of Squares) Success! -8.825100588289303-
# - calc ECV(Explained Cluster Variance) Success! -45.72417862859829-
# 9 : TSS: 16.259727380080342, WSS: 8.825100588289303, ECV: 45.72417862859829
# ---Now 10---
# ---Cluster Init Okay KMeans Start---
# - calc TSS(Total Sum Of Squareds Success! -16.259727380080342-
# - calc WSS(Within clusterSum Of Squares) Success! -8.773038753189791-
# - calc ECV(Explained Cluster Variance) Success! -46.04436748467524-
# 10 : TSS: 16.259727380080342, WSS: 8.773038753189791, ECV: 46.04436748467524
# ---Now 11---
# ---Cluster Init Okay KMeans Start---
# - calc TSS(Total Sum Of Squareds Success! -16.259727380080342-
# - calc WSS(Within clusterSum Of Squares) Success! -8.773038753189791-
# - calc ECV(Explained Cluster Variance) Success! -46.04436748467524-
# 11 : TSS: 16.259727380080342, WSS: 8.773038753189791, ECV: 46.04436748467524
# 아파트2-2-807: pattern recognition start
# ---Init KMeans---
# ---init TSS Check---
# - calc TSS(Total Sum Of Squareds Success! -88.56503780434781-
# ---Remove One Pattern---
# ---Dimension Reduction---
# - remove one pattern success: 92 => 63
# - calc TSS(Total Sum Of Squareds Success! -58.68506552528357-
# ---Remove Outliers---
# - dis_check: 1.0727549356999406, sim_check: 0.3935764725159333
# - remove outlier success: 63 => 61
# - calc TSS(Total Sum Of Squareds Success! -56.99255502103026-
# ---K Setting 6 ---
# ---6:Clustering Start---
# ---Now 1---
# ---First Cluster Group Init---
# ---Init Cluster---
# ---First K Is Mean Pattern---
# ---Rest K Select---
# ---Divide Index---
# 1: calc... [60, 0]
# 1: [60, 0, 30]
# 2: calc... [60, 30, 0]
# 2: calc... [60, 30, 0, 45]
# 2: [60, 30, 0, 45, 15]
# 4: calc... [60, 45, 30, 15, 0]
# 4: calc... [60, 45, 30, 15, 0, 53]
# 4: calc... [60, 45, 30, 15, 0, 53, 38]
# 4: calc... [60, 45, 30, 15, 0, 53, 38, 23]
# 4: [60, 45, 30, 15, 0, 53, 38, 23, 8]
# -1: K Setting Okay
# -2: K Setting Okay
# -3: K Setting Okay
# -4: K Setting Okay
# -5: K Setting Okay
# ---Cluster Init Okay KMeans Start---
# - calc TSS(Total Sum Of Squareds Success! -56.99255502103026-
# - calc WSS(Within clusterSum Of Squares) Success! -37.99163160302459-
# - calc ECV(Explained Cluster Variance) Success! -33.339307934157944-
# 1 : TSS: 56.99255502103026, WSS: 37.99163160302459, ECV: 33.339307934157944
# ---Now 2---
# ---Cluster Init Okay KMeans Start---
# - calc TSS(Total Sum Of Squareds Success! -56.99255502103026-
# - calc WSS(Within clusterSum Of Squares) Success! -29.22605223766963-
# - calc ECV(Explained Cluster Variance) Success! -48.71952621375685-
# 2 : TSS: 56.99255502103026, WSS: 29.22605223766963, ECV: 48.71952621375685
# ---Now 3---
# ---Cluster Init Okay KMeans Start---
# - calc TSS(Total Sum Of Squareds Success! -56.99255502103026-
# - calc WSS(Within clusterSum Of Squares) Success! -28.881165220143604-
# - calc ECV(Explained Cluster Variance) Success! -49.32467019685913-
# 3 : TSS: 56.99255502103026, WSS: 28.881165220143604, ECV: 49.32467019685913
# ---Now 4---
# ---Cluster Init Okay KMeans Start---
# - calc TSS(Total Sum Of Squareds Success! -56.99255502103026-
# - calc WSS(Within clusterSum Of Squares) Success! -28.356120725925916-
# - calc ECV(Explained Cluster Variance) Success! -50.24592121644221-
# 4 : TSS: 56.99255502103026, WSS: 28.356120725925916, ECV: 50.24592121644221
# ---Now 5---
# ---Cluster Init Okay KMeans Start---
# - calc TSS(Total Sum Of Squareds Success! -56.99255502103026-
# - calc WSS(Within clusterSum Of Squares) Success! -28.356120725925916-
# - calc ECV(Explained Cluster Variance) Success! -50.24592121644221-
# 5 : TSS: 56.99255502103026, WSS: 28.356120725925916, ECV: 50.24592121644221
# 아파트3-103-123: pattern recognition start
# ---Init KMeans---
# ---init TSS Check---
# - calc TSS(Total Sum Of Squareds Success! -167.57664577173915-
# ---Remove One Pattern---
# ---Dimension Reduction---
# - remove one pattern success: 92 => 92
# - calc TSS(Total Sum Of Squareds Success! -167.57664577173915-
# ---Remove Outliers---
# - dis_check: 0.9547295479733258, sim_check: 0.13159463338515487
# - remove outlier success: 92 => 89
# - calc TSS(Total Sum Of Squareds Success! -149.97159012299153-
# ---K Setting 7 ---
# ---7:Clustering Start---
# ---Now 1---
# ---First Cluster Group Init---
# ---Init Cluster---
# ---First K Is Mean Pattern---
# ---Rest K Select---
# ---Divide Index---
# 1: calc... [88, 0]
# 1: [88, 0, 44]
# 2: calc... [88, 44, 0]
# 2: calc... [88, 44, 0, 66]
# 2: [88, 44, 0, 66, 22]
# 4: calc... [88, 66, 44, 22, 0]
# 4: calc... [88, 66, 44, 22, 0, 77]
# 4: calc... [88, 66, 44, 22, 0, 77, 55]
# 4: calc... [88, 66, 44, 22, 0, 77, 55, 33]
# 4: [88, 66, 44, 22, 0, 77, 55, 33, 11]
# -1: K Setting Okay
# -2: K Setting Okay
# -3: K Setting Okay
# -4: K Setting Okay
# -5: K Setting Okay
# -6: K Setting Okay
# ---Cluster Init Okay KMeans Start---
# - calc TSS(Total Sum Of Squareds Success! -149.97159012299153-
# - calc WSS(Within clusterSum Of Squares) Success! -105.73069789862951-
# - calc ECV(Explained Cluster Variance) Success! -29.49951533359092-
# 1 : TSS: 149.97159012299153, WSS: 105.73069789862951, ECV: 29.49951533359092
# ---Now 2---
# ---Cluster Init Okay KMeans Start---
# - calc TSS(Total Sum Of Squareds Success! -149.97159012299153-
# - calc WSS(Within clusterSum Of Squares) Success! -79.05753738147524-
# - calc ECV(Explained Cluster Variance) Success! -47.2849908995162-
# 2 : TSS: 149.97159012299153, WSS: 79.05753738147524, ECV: 47.2849908995162
# ---Now 3---
# ---Cluster Init Okay KMeans Start---
# - calc TSS(Total Sum Of Squareds Success! -149.97159012299153-
# - calc WSS(Within clusterSum Of Squares) Success! -76.59822002168856-
# - calc ECV(Explained Cluster Variance) Success! -48.92484639332659-
# 3 : TSS: 149.97159012299153, WSS: 76.59822002168856, ECV: 48.92484639332659
# ---Now 4---
# ---Cluster Init Okay KMeans Start---
# - calc TSS(Total Sum Of Squareds Success! -149.97159012299153-
# - calc WSS(Within clusterSum Of Squares) Success! -75.96591596908122-
# - calc ECV(Explained Cluster Variance) Success! -49.34646228210179-
# 4 : TSS: 149.97159012299153, WSS: 75.96591596908122, ECV: 49.34646228210179
# ---Now 5---
# ---Cluster Init Okay KMeans Start---
# - calc TSS(Total Sum Of Squareds Success! -149.97159012299153-
# - calc WSS(Within clusterSum Of Squares) Success! -75.29688827091752-
# - calc ECV(Explained Cluster Variance) Success! -49.79256523907852-
# 5 : TSS: 149.97159012299153, WSS: 75.29688827091752, ECV: 49.79256523907852
# ---Now 6---
# ---Cluster Init Okay KMeans Start---
# - calc TSS(Total Sum Of Squareds Success! -149.97159012299153-
# - calc WSS(Within clusterSum Of Squares) Success! -75.12452485295697-
# - calc ECV(Explained Cluster Variance) Success! -49.90749595216839-
# 6 : TSS: 149.97159012299153, WSS: 75.12452485295697, ECV: 49.90749595216839
# ---Now 7---
# ---Cluster Init Okay KMeans Start---
# - calc TSS(Total Sum Of Squareds Success! -149.97159012299153-
# - calc WSS(Within clusterSum Of Squares) Success! -75.12452485295697-
# - calc ECV(Explained Cluster Variance) Success! -49.90749595216839-
# 7 : TSS: 149.97159012299153, WSS: 75.12452485295697, ECV: 49.90749595216839
# 아파트3-101-1906: pattern recognition start
# ---Init KMeans---
# ---init TSS Check---
# - calc TSS(Total Sum Of Squareds Success! -16.470083065217388-
# ---Remove One Pattern---
# ---Dimension Reduction---
# - remove one pattern success: 92 => 92
# - calc TSS(Total Sum Of Squareds Success! -16.470083065217388-
# ---Remove Outliers---
# - dis_check: 0.49091824957877606, sim_check: 0.6534677749628218
# - remove outlier success: 92 => 83
# - calc TSS(Total Sum Of Squareds Success! -10.116878865075616-
# ---K Setting 6 ---
# ---6:Clustering Start---
# ---Now 1---
# ---First Cluster Group Init---
# ---Init Cluster---
# ---First K Is Mean Pattern---
# ---Rest K Select---
# ---Divide Index---
# 1: calc... [82, 0]
# 1: [82, 0, 41]
# 2: calc... [82, 41, 0]
# 2: calc... [82, 41, 0, 62]
# 2: [82, 41, 0, 62, 21]
# 4: calc... [82, 62, 41, 21, 0]
# 4: calc... [82, 62, 41, 21, 0, 72]
# 4: calc... [82, 62, 41, 21, 0, 72, 52]
# 4: calc... [82, 62, 41, 21, 0, 72, 52, 31]
# 4: [82, 62, 41, 21, 0, 72, 52, 31, 11]
# -1: K Setting Okay
# -2: K Setting Okay
# -3: K Setting Okay
# -4: K Setting Okay
# -5: K Setting Okay
# ---Cluster Init Okay KMeans Start---
# - calc TSS(Total Sum Of Squareds Success! -10.116878865075616-
# - calc WSS(Within clusterSum Of Squares) Success! -8.489538938563333-
# - calc ECV(Explained Cluster Variance) Success! -16.08539499400362-
# 1 : TSS: 10.116878865075616, WSS: 8.489538938563333, ECV: 16.08539499400362
# ---Now 2---
# ---Cluster Init Okay KMeans Start---
# - calc TSS(Total Sum Of Squareds Success! -10.116878865075616-
# - calc WSS(Within clusterSum Of Squares) Success! -7.1066518048285126-
# - calc ECV(Explained Cluster Variance) Success! -29.75450334429407-
# 2 : TSS: 10.116878865075616, WSS: 7.1066518048285126, ECV: 29.75450334429407
# ---Now 3---
# ---Cluster Init Okay KMeans Start---
# - calc TSS(Total Sum Of Squareds Success! -10.116878865075616-
# - calc WSS(Within clusterSum Of Squares) Success! -6.7215175277777774-
# - calc ECV(Explained Cluster Variance) Success! -33.56135209860952-
# 3 : TSS: 10.116878865075616, WSS: 6.7215175277777774, ECV: 33.56135209860952
# ---Now 4---
# ---Cluster Init Okay KMeans Start---
# - calc TSS(Total Sum Of Squareds Success! -10.116878865075616-
# - calc WSS(Within clusterSum Of Squares) Success! -6.534131396108823-
# - calc ECV(Explained Cluster Variance) Success! -35.413564961568945-
# 4 : TSS: 10.116878865075616, WSS: 6.534131396108823, ECV: 35.413564961568945
# ---Now 5---
# ---Cluster Init Okay KMeans Start---
# - calc TSS(Total Sum Of Squareds Success! -10.116878865075616-
# - calc WSS(Within clusterSum Of Squares) Success! -6.508808494032952-
# - calc ECV(Explained Cluster Variance) Success! -35.663868463405755-
# 5 : TSS: 10.116878865075616, WSS: 6.508808494032952, ECV: 35.663868463405755
# ---Now 6---
# ---Cluster Init Okay KMeans Start---
# - calc TSS(Total Sum Of Squareds Success! -10.116878865075616-
# - calc WSS(Within clusterSum Of Squares) Success! -6.505666033465334-
# - calc ECV(Explained Cluster Variance) Success! -35.6949300250744-
# 6 : TSS: 10.116878865075616, WSS: 6.505666033465334, ECV: 35.6949300250744
# ---Now 7---
# ---Cluster Init Okay KMeans Start---
# - calc TSS(Total Sum Of Squareds Success! -10.116878865075616-
# - calc WSS(Within clusterSum Of Squares) Success! -6.496289430555557-
# - calc ECV(Explained Cluster Variance) Success! -35.787612788551435-
# 7 : TSS: 10.116878865075616, WSS: 6.496289430555557, ECV: 35.787612788551435
# ---Now 8---
# ---Cluster Init Okay KMeans Start---
# - calc TSS(Total Sum Of Squareds Success! -10.116878865075616-
# - calc WSS(Within clusterSum Of Squares) Success! -6.496289430555557-
# - calc ECV(Explained Cluster Variance) Success! -35.787612788551435-
# 8 : TSS: 10.116878865075616, WSS: 6.496289430555557, ECV: 35.787612788551435
# 아파트1-103-1504: pattern recognition start
# ---Init KMeans---
# ---init TSS Check---
# - calc TSS(Total Sum Of Squareds Success! -40.99685089130435-
# ---Remove One Pattern---
# ---Dimension Reduction---
# - remove one pattern success: 92 => 92
# - calc TSS(Total Sum Of Squareds Success! -40.99685089130435-
# ---Remove Outliers---
# - dis_check: 0.9738283251476931, sim_check: 0.2536259952563169
# - remove outlier success: 92 => 88
# - calc TSS(Total Sum Of Squareds Success! -36.26149790831759-
# ---K Setting 7 ---
# ---7:Clustering Start---
# ---Now 1---
# ---First Cluster Group Init---
# ---Init Cluster---
# ---First K Is Mean Pattern---
# ---Rest K Select---
# ---Divide Index---
# 1: calc... [87, 0]
# 1: [87, 0, 44]
# 2: calc... [87, 44, 0]
# 2: calc... [87, 44, 0, 66]
# 2: [87, 44, 0, 66, 22]
# 4: calc... [87, 66, 44, 22, 0]
# 4: calc... [87, 66, 44, 22, 0, 77]
# 4: calc... [87, 66, 44, 22, 0, 77, 55]
# 4: calc... [87, 66, 44, 22, 0, 77, 55, 33]
# 4: [87, 66, 44, 22, 0, 77, 55, 33, 11]
# -1: K Setting Okay
# -2: K Setting Okay
# -3: K Setting Okay
# -4: K Setting Okay
# -5: K Setting Okay
# -6: K Setting Okay
# ---Cluster Init Okay KMeans Start---
# - calc TSS(Total Sum Of Squareds Success! -36.26149790831759-
# - calc WSS(Within clusterSum Of Squares) Success! -25.517318564272205-
# - calc ECV(Explained Cluster Variance) Success! -29.629717369124187-
# 1 : TSS: 36.26149790831759, WSS: 25.517318564272205, ECV: 29.629717369124187
# ---Now 2---
# ---Cluster Init Okay KMeans Start---
# - calc TSS(Total Sum Of Squareds Success! -36.26149790831759-
# - calc WSS(Within clusterSum Of Squares) Success! -17.038462384507277-
# - calc ECV(Explained Cluster Variance) Success! -53.01224889389076-
# 2 : TSS: 36.26149790831759, WSS: 17.038462384507277, ECV: 53.01224889389076
# ---Now 3---
# ---Cluster Init Okay KMeans Start---
# - calc TSS(Total Sum Of Squareds Success! -36.26149790831759-
# - calc WSS(Within clusterSum Of Squares) Success! -16.204973610339362-
# - calc ECV(Explained Cluster Variance) Success! -55.31079920826354-
# 3 : TSS: 36.26149790831759, WSS: 16.204973610339362, ECV: 55.31079920826354
# ---Now 4---
# ---Cluster Init Okay KMeans Start---
# - calc TSS(Total Sum Of Squareds Success! -36.26149790831759-
# - calc WSS(Within clusterSum Of Squares) Success! -16.01525309757576-
# - calc ECV(Explained Cluster Variance) Success! -55.834000189213874-
# 4 : TSS: 36.26149790831759, WSS: 16.01525309757576, ECV: 55.834000189213874
# ---Now 5---
# ---Cluster Init Okay KMeans Start---
# - calc TSS(Total Sum Of Squareds Success! -36.26149790831759-
# - calc WSS(Within clusterSum Of Squares) Success! -15.937710547071724-
# - calc ECV(Explained Cluster Variance) Success! -56.04784284596263-
# 5 : TSS: 36.26149790831759, WSS: 15.937710547071724, ECV: 56.04784284596263
# ---Now 6---
# ---Cluster Init Okay KMeans Start---
# - calc TSS(Total Sum Of Squareds Success! -36.26149790831759-
# - calc WSS(Within clusterSum Of Squares) Success! -15.873526707575756-
# - calc ECV(Explained Cluster Variance) Success! -56.22484557116236-
# 6 : TSS: 36.26149790831759, WSS: 15.873526707575756, ECV: 56.22484557116236
# ---Now 7---
# ---Cluster Init Okay KMeans Start---
# - calc TSS(Total Sum Of Squareds Success! -36.26149790831759-
# - calc WSS(Within clusterSum Of Squares) Success! -15.873526707575756-
# - calc ECV(Explained Cluster Variance) Success! -56.22484557116236-
# 7 : TSS: 36.26149790831759, WSS: 15.873526707575756, ECV: 56.22484557116236
# 아파트4-103-1406: pattern recognition start
# ---Init KMeans---
# ---init TSS Check---
# - calc TSS(Total Sum Of Squareds Success! -21.59937019565218-
# ---Remove One Pattern---
# ---Dimension Reduction---
# - remove one pattern success: 92 => 92
# - calc TSS(Total Sum Of Squareds Success! -21.59937019565218-
# ---Remove Outliers---
# - dis_check: 0.6078644401863815, sim_check: 0.2504652659114466
# - remove outlier success: 92 => 82
# - calc TSS(Total Sum Of Squareds Success! -15.408511673440453-
# ---K Setting 6 ---
# ---6:Clustering Start---
# ---Now 1---
# ---First Cluster Group Init---
# ---Init Cluster---
# ---First K Is Mean Pattern---
# ---Rest K Select---
# ---Divide Index---
# 1: calc... [81, 0]
# 1: [81, 0, 41]
# 2: calc... [81, 41, 0]
# 2: calc... [81, 41, 0, 61]
# 2: [81, 41, 0, 61, 21]
# 4: calc... [81, 61, 41, 21, 0]
# 4: calc... [81, 61, 41, 21, 0, 71]
# 4: calc... [81, 61, 41, 21, 0, 71, 51]
# 4: calc... [81, 61, 41, 21, 0, 71, 51, 31]
# 4: [81, 61, 41, 21, 0, 71, 51, 31, 11]
# -1: K Setting Okay
# -2: K Setting Okay
# -3: K Setting Okay
# -4: K Setting Okay
# -5: K Setting Okay
# ---Cluster Init Okay KMeans Start---
# - calc TSS(Total Sum Of Squareds Success! -15.408511673440453-
# - calc WSS(Within clusterSum Of Squares) Success! -11.490542163043477-
# - calc ECV(Explained Cluster Variance) Success! -25.427306630466806-
# 1 : TSS: 15.408511673440453, WSS: 11.490542163043477, ECV: 25.427306630466806
# ---Now 2---
# ---Cluster Init Okay KMeans Start---
# - calc TSS(Total Sum Of Squareds Success! -15.408511673440453-
# - calc WSS(Within clusterSum Of Squares) Success! -8.920277431265262-
# - calc ECV(Explained Cluster Variance) Success! -42.10811777077027-
# 2 : TSS: 15.408511673440453, WSS: 8.920277431265262, ECV: 42.10811777077027
# ---Now 3---
# ---Cluster Init Okay KMeans Start---
# - calc TSS(Total Sum Of Squareds Success! -15.408511673440453-
# - calc WSS(Within clusterSum Of Squares) Success! -8.636698681514472-
# - calc ECV(Explained Cluster Variance) Success! -43.94852102165395-
# 3 : TSS: 15.408511673440453, WSS: 8.636698681514472, ECV: 43.94852102165395
# ---Now 4---
# ---Cluster Init Okay KMeans Start---
# - calc TSS(Total Sum Of Squareds Success! -15.408511673440453-
# - calc WSS(Within clusterSum Of Squares) Success! -8.625372358826358-
# - calc ECV(Explained Cluster Variance) Success! -44.022027943854866-
# 4 : TSS: 15.408511673440453, WSS: 8.625372358826358, ECV: 44.022027943854866
# ---Now 5---
# ---Cluster Init Okay KMeans Start---
# - calc TSS(Total Sum Of Squareds Success! -15.408511673440453-
# - calc WSS(Within clusterSum Of Squares) Success! -8.613514980885782-
# - calc ECV(Explained Cluster Variance) Success! -44.098981371881365-
# 5 : TSS: 15.408511673440453, WSS: 8.613514980885782, ECV: 44.098981371881365
# ---Now 6---
# ---Cluster Init Okay KMeans Start---
# - calc TSS(Total Sum Of Squareds Success! -15.408511673440453-
# - calc WSS(Within clusterSum Of Squares) Success! -8.613514980885782-
# - calc ECV(Explained Cluster Variance) Success! -44.098981371881365-
# 6 : TSS: 15.408511673440453, WSS: 8.613514980885782, ECV: 44.098981371881365
# 아파트1-104-503: pattern recognition start
# ---Init KMeans---
# ---init TSS Check---
# - calc TSS(Total Sum Of Squareds Success! -18.564331847826086-
# ---Remove One Pattern---
# ---Dimension Reduction---
# - remove one pattern success: 92 => 91
# - calc TSS(Total Sum Of Squareds Success! -18.38632408530246-
# ---Remove Outliers---
# - dis_check: 0.6897216218334565, sim_check: 0.232130368173736
# - remove outlier success: 91 => 82
# - calc TSS(Total Sum Of Squareds Success! -13.372490613894136-
# ---K Setting 6 ---
# ---6:Clustering Start---
# ---Now 1---
# ---First Cluster Group Init---
# ---Init Cluster---
# ---First K Is Mean Pattern---
# ---Rest K Select---
# ---Divide Index---
# 1: calc... [81, 0]
# 1: [81, 0, 41]
# 2: calc... [81, 41, 0]
# 2: calc... [81, 41, 0, 61]
# 2: [81, 41, 0, 61, 21]
# 4: calc... [81, 61, 41, 21, 0]
# 4: calc... [81, 61, 41, 21, 0, 71]
# 4: calc... [81, 61, 41, 21, 0, 71, 51]
# 4: calc... [81, 61, 41, 21, 0, 71, 51, 31]
# 4: [81, 61, 41, 21, 0, 71, 51, 31, 11]
# -1: K Setting Okay
# -2: K Setting Okay
# -3: K Setting Okay
# -4: K Setting Okay
# -5: K Setting Okay
# ---Cluster Init Okay KMeans Start---
# - calc TSS(Total Sum Of Squareds Success! -13.372490613894136-
# - calc WSS(Within clusterSum Of Squares) Success! -9.813461480860113-
# - calc ECV(Explained Cluster Variance) Success! -26.614556972178093-
# 1 : TSS: 13.372490613894136, WSS: 9.813461480860113, ECV: 26.614556972178093
# ---Now 2---
# ---Cluster Init Okay KMeans Start---
# - calc TSS(Total Sum Of Squareds Success! -13.372490613894136-
# - calc WSS(Within clusterSum Of Squares) Success! -7.014546122643589-
# - calc ECV(Explained Cluster Variance) Success! -47.544953852086365-
# 2 : TSS: 13.372490613894136, WSS: 7.014546122643589, ECV: 47.544953852086365
# ---Now 3---
# ---Cluster Init Okay KMeans Start---
# - calc TSS(Total Sum Of Squareds Success! -13.372490613894136-
# - calc WSS(Within clusterSum Of Squares) Success! -6.929674385266849-
# - calc ECV(Explained Cluster Variance) Success! -48.17962797396279-
# 3 : TSS: 13.372490613894136, WSS: 6.929674385266849, ECV: 48.17962797396279
# ---Now 4---
# ---Cluster Init Okay KMeans Start---
# - calc TSS(Total Sum Of Squareds Success! -13.372490613894136-
# - calc WSS(Within clusterSum Of Squares) Success! -6.901830234167843-
# - calc ECV(Explained Cluster Variance) Success! -48.387847608606435-
# 4 : TSS: 13.372490613894136, WSS: 6.901830234167843, ECV: 48.387847608606435
# ---Now 5---
# ---Cluster Init Okay KMeans Start---
# - calc TSS(Total Sum Of Squareds Success! -13.372490613894136-
# - calc WSS(Within clusterSum Of Squares) Success! -6.88125403620091-
# - calc ECV(Explained Cluster Variance) Success! -48.541717209722876-
# 5 : TSS: 13.372490613894136, WSS: 6.88125403620091, ECV: 48.541717209722876
# ---Now 6---
# ---Cluster Init Okay KMeans Start---
# - calc TSS(Total Sum Of Squareds Success! -13.372490613894136-
# - calc WSS(Within clusterSum Of Squares) Success! -6.8673320651552245-
# - calc ECV(Explained Cluster Variance) Success! -48.64582624556113-
# 6 : TSS: 13.372490613894136, WSS: 6.8673320651552245, ECV: 48.64582624556113
# ---Now 7---
# ---Cluster Init Okay KMeans Start---
# - calc TSS(Total Sum Of Squareds Success! -13.372490613894136-
# - calc WSS(Within clusterSum Of Squares) Success! -6.8673320651552245-
# - calc ECV(Explained Cluster Variance) Success! -48.64582624556113-
# 7 : TSS: 13.372490613894136, WSS: 6.8673320651552245, ECV: 48.64582624556113
# 아파트3-101-201: pattern recognition start
# ---Init KMeans---
# ---init TSS Check---
# - calc TSS(Total Sum Of Squareds Success! -34.66377865217392-
# ---Remove One Pattern---
# ---Dimension Reduction---
# - remove one pattern success: 92 => 92
# - calc TSS(Total Sum Of Squareds Success! -34.66377865217392-
# ---Remove Outliers---
# - dis_check: 0.8541930693478401, sim_check: 0.1775460695059201
# - remove outlier success: 92 => 89
# - calc TSS(Total Sum Of Squareds Success! -31.90915165170132-
# ---K Setting 7 ---
# ---7:Clustering Start---
# ---Now 1---
# ---First Cluster Group Init---
# ---Init Cluster---
# ---First K Is Mean Pattern---
# ---Rest K Select---
# ---Divide Index---
# 1: calc... [88, 0]
# 1: [88, 0, 44]
# 2: calc... [88, 44, 0]
# 2: calc... [88, 44, 0, 66]
# 2: [88, 44, 0, 66, 22]
# 4: calc... [88, 66, 44, 22, 0]
# 4: calc... [88, 66, 44, 22, 0, 77]
# 4: calc... [88, 66, 44, 22, 0, 77, 55]
# 4: calc... [88, 66, 44, 22, 0, 77, 55, 33]
# 4: [88, 66, 44, 22, 0, 77, 55, 33, 11]
# -1: K Setting Okay
# -2: K Setting Okay
# -3: K Setting Okay
# -4: K Setting Okay
# -5: K Setting Okay
# -6: K Setting Okay
# ---Cluster Init Okay KMeans Start---
# - calc TSS(Total Sum Of Squareds Success! -31.90915165170132-
# - calc WSS(Within clusterSum Of Squares) Success! -24.23599802977316-
# - calc ECV(Explained Cluster Variance) Success! -24.046874406700326-
# 1 : TSS: 31.90915165170132, WSS: 24.23599802977316, ECV: 24.046874406700326
# ---Now 2---
# ---Cluster Init Okay KMeans Start---
# - calc TSS(Total Sum Of Squareds Success! -31.90915165170132-
# - calc WSS(Within clusterSum Of Squares) Success! -20.02940636835119-
# - calc ECV(Explained Cluster Variance) Success! -37.22990010208163-
# 2 : TSS: 31.90915165170132, WSS: 20.02940636835119, ECV: 37.22990010208163
# ---Now 3---
# ---Cluster Init Okay KMeans Start---
# - calc TSS(Total Sum Of Squareds Success! -31.90915165170132-
# - calc WSS(Within clusterSum Of Squares) Success! -19.039434380912276-
# - calc ECV(Explained Cluster Variance) Success! -40.33237051008487-
# 3 : TSS: 31.90915165170132, WSS: 19.039434380912276, ECV: 40.33237051008487
# ---Now 4---
# ---Cluster Init Okay KMeans Start---
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-53-832fc1bc89bc> in <module>
#       6     datas.merging()
#       7     print("{}: pattern recognition start".format(datas.uid))
# ----> 8     KMeans(datas.merge_datas['봄']).run()
#       9
#      10 db.close()
#
# ~/Desktop/formegusto/research/kmeans-euclidean-cosine/modules/KMeans.py in run(self, K)
#     213                 sim_info = pd.DataFrame(columns=cols)
#     214                 for row in rows:
# --> 215                     sim_info.loc[row] = [
#     216                         utils.euclidean_distance(
#     217                             self.cluster_dict[row],
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#     690
#     691         iloc = self if self.name == "iloc" else self.obj.iloc
# --> 692         iloc._setitem_with_indexer(indexer, value, self.name)
#     693
#     694     def _validate_key(self, key, axis: int):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _setitem_with_indexer(self, indexer, value, name)
#    1627
#    1628             if missing:
# -> 1629                 self._setitem_with_indexer_missing(indexer, value)
#    1630                 return
#    1631
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _setitem_with_indexer_missing(self, indexer, value)
#    1920                 value = Series(value, index=self.obj.columns, name=indexer)
#    1921
# -> 1922             self.obj._mgr = self.obj.append(value)._mgr
#    1923             self.obj._maybe_update_cacher(clear=True)
#    1924
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in append(self, other, ignore_index, verify_integrity, sort)
#    7980             to_concat = [self, other]
#    7981         return (
# -> 7982             concat(
#    7983                 to_concat,
#    7984                 ignore_index=ignore_index,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     296     )
#     297
# --> 298     return op.get_result()
#     299
#     300
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/concat.py in get_result(self)
#     518                 mgrs_indexers.append((obj._mgr, indexers))
#     519
# --> 520             new_data = concatenate_block_managers(
#     521                 mgrs_indexers, self.new_axes, concat_axis=self.bm_axis, copy=self.copy
#     522             )
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/concat.py in concatenate_block_managers(mgrs_indexers, axes, concat_axis, copy)
#      87         blocks.append(b)
#      88
# ---> 89     return BlockManager(blocks, axes)
#      90
#      91
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/managers.py in __init__(self, blocks, axes, do_integrity_check)
#     130         do_integrity_check: bool = True,
#     131     ):
# --> 132         self.axes = [ensure_index(ax) for ax in axes]
#     133         self.blocks: Tuple[Block, ...] = tuple(blocks)
#     134
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/managers.py in <listcomp>(.0)
#     130         do_integrity_check: bool = True,
#     131     ):
# --> 132         self.axes = [ensure_index(ax) for ax in axes]
#     133         self.blocks: Tuple[Block, ...] = tuple(blocks)
#     134
#
# KeyboardInterrupt:

# %%
# KETIDB Utils Test
db.connect()

datas = db.find_one("아파트1-103-106", processing=True)
datas.merging()
print("{}: pattern recognition start".format(datas.uid))
KMeans(datas.merge_datas['봄']).run()


db.close()
# Out:
# connect KETIDB,,,
# connect success!!
# 아파트1-103-106: pattern recognition start
# ---Init KMeans---
# ---init TSS Check---
# - calc TSS(Total Sum Of Squareds Success! -112.36219710869557-
# ---Remove One Pattern---
# ---Dimension Reduction---
# - remove one pattern success: 92 => 92
# - calc TSS(Total Sum Of Squareds Success! -112.36219710869557-
# ---Remove Outliers---
# - dis_check: 1.6998900765459728, sim_check: -0.3290371870914794
# - remove outlier success: 92 => 92
# - calc TSS(Total Sum Of Squareds Success! -112.36219710869557-
# ---K Setting 7 ---
# ---7:Clustering Start---
# ---Now 1---
# ---First Cluster Group Init---
# ---Init Cluster---
# ---First K Is Mean Pattern---
# ---Rest K Select---
# ---Divide Index---
# 1: calc... [91, 0]
# 1: [91, 0, 46]
# 2: calc... [91, 46, 0]
# 2: calc... [91, 46, 0, 69]
# 2: [91, 46, 0, 69, 23]
# 4: calc... [91, 69, 46, 23, 0]
# 4: calc... [91, 69, 46, 23, 0, 80]
# 4: calc... [91, 69, 46, 23, 0, 80, 58]
# 4: calc... [91, 69, 46, 23, 0, 80, 58, 35]
# 4: [91, 69, 46, 23, 0, 80, 58, 35, 12]
# -1: K Setting Okay
# -2: K Setting Okay
# -3: K Setting Okay
# -4: K Setting Okay
# -5: K Setting Okay
# -6: K Setting Okay
# ---Cluster Init Okay KMeans Start---
# - calc TSS(Total Sum Of Squareds Success! -112.36219710869557-
# - calc WSS(Within clusterSum Of Squares) Success! -17.1571943889414-
# - calc ECV(Explained Cluster Variance) Success! -84.73045665674898-
# 1 : TSS: 112.36219710869557, WSS: 17.1571943889414, ECV: 84.73045665674898
# ---Now 2---
# ---Cluster Init Okay KMeans Start---
# - calc TSS(Total Sum Of Squareds Success! -112.36219710869557-
# - calc WSS(Within clusterSum Of Squares) Success! -10.964636373144025-
# - calc ECV(Explained Cluster Variance) Success! -90.2417034774274-
# 2 : TSS: 112.36219710869557, WSS: 10.964636373144025, ECV: 90.2417034774274
# ---Now 3---
# ---Cluster Init Okay KMeans Start---
# - calc TSS(Total Sum Of Squareds Success! -112.36219710869557-
# - calc WSS(Within clusterSum Of Squares) Success! -10.599343723021525-
# - calc ECV(Explained Cluster Variance) Success! -90.56680627847811-
# 3 : TSS: 112.36219710869557, WSS: 10.599343723021525, ECV: 90.56680627847811
# ---Now 4---
# ---Cluster Init Okay KMeans Start---
# - calc TSS(Total Sum Of Squareds Success! -112.36219710869557-
# - calc WSS(Within clusterSum Of Squares) Success! -10.319532720771832-
# - calc ECV(Explained Cluster Variance) Success! -90.81583220485707-
# 4 : TSS: 112.36219710869557, WSS: 10.319532720771832, ECV: 90.81583220485707
# ---Now 5---
# ---Cluster Init Okay KMeans Start---
# - calc TSS(Total Sum Of Squareds Success! -112.36219710869557-
# - calc WSS(Within clusterSum Of Squares) Success! -10.173142181193866-
# - calc ECV(Explained Cluster Variance) Success! -90.94611671632524-
# 5 : TSS: 112.36219710869557, WSS: 10.173142181193866, ECV: 90.94611671632524
# ---Now 6---
# ---Cluster Init Okay KMeans Start---
# - calc TSS(Total Sum Of Squareds Success! -112.36219710869557-
# - calc WSS(Within clusterSum Of Squares) Success! -10.121670193553948-
# - calc ECV(Explained Cluster Variance) Success! -90.99192570632756-
# 6 : TSS: 112.36219710869557, WSS: 10.121670193553948, ECV: 90.99192570632756
# ---Now 7---
# ---Cluster Init Okay KMeans Start---
# - calc TSS(Total Sum Of Squareds Success! -112.36219710869557-
# - calc WSS(Within clusterSum Of Squares) Success! -10.065156461297983-
# - calc ECV(Explained Cluster Variance) Success! -91.04222174334909-
# 7 : TSS: 112.36219710869557, WSS: 10.065156461297983, ECV: 91.04222174334909
# ---Now 8---
# ---Cluster Init Okay KMeans Start---
# - calc TSS(Total Sum Of Squareds Success! -112.36219710869557-
# - calc WSS(Within clusterSum Of Squares) Success! -10.03855417155076-
# - calc ECV(Explained Cluster Variance) Success! -91.06589722356551-
# 8 : TSS: 112.36219710869557, WSS: 10.03855417155076, ECV: 91.06589722356551
# ---Now 9---
# ---Cluster Init Okay KMeans Start---
# - calc TSS(Total Sum Of Squareds Success! -112.36219710869557-
# - calc WSS(Within clusterSum Of Squares) Success! -10.012604086591791-
# - calc ECV(Explained Cluster Variance) Success! -91.08899225519245-
# 9 : TSS: 112.36219710869557, WSS: 10.012604086591791, ECV: 91.08899225519245
# ---Now 10---
# ---Cluster Init Okay KMeans Start---
# - calc TSS(Total Sum Of Squareds Success! -112.36219710869557-
# - calc WSS(Within clusterSum Of Squares) Success! -10.012604086591791-
# - calc ECV(Explained Cluster Variance) Success! -91.08899225519245-
# 10 : TSS: 112.36219710869557, WSS: 10.012604086591791, ECV: 91.08899225519245
# disconnect KETIDB,,,
# disconnect success!!
